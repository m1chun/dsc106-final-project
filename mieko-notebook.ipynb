# %% [markdown]
# # Final Project Checkpoint

# %% [markdown]
# ## Seed Zones Data

# %%
import pandas as pd

seed_zone_df = pd.read_csv("ca-seed-zones.csv")
seed_zone_df
# Out:
#     OBJECTID  SEED_ZONE  REGION  SUBREGION  SUBZONE   Shape__Area  \
# 0          1         91       0          9        1  1.346744e+09
# 1          2        301       3          0        1  2.541819e+09
# 2          3        512       5          1        2  1.727634e+08
# 3          4        511       5          1        1  2.717440e+08
# 4          5        321       3          2        1  1.569239e+09
# ..       ...        ...     ...        ...      ...           ...
# 87        88        986       9          8        6  6.602299e+09
# 88        89        998       9          9        8  8.057870e+09
# 89        90        150       1          5        0  1.939695e+08
# 90        91        150       1          5        0  5.858490e+07
# 91        92        150       1          5        0  1.468020e+08
#
#     Shape__Length                              GlobalID
# 0   202368.859869  babe457c-5ab6-4430-be80-b8ab44f90604
# 1   234810.252618  05611a6e-e5ee-456b-990c-0a9aad6f358d
# ...

# %%
seed_zone_df['SEED_ZONE'].unique()
# Out:
# array([ 91, 301, 512, 511, 321, 516, 720, 731, 952, 751, 741, 322, 742,
#        302, 311,  92, 752, 521, 331, 303, 312, 732, 332, 522, 760, 390,
#         93, 961, 340, 371, 771, 524, 523, 351,  94, 372, 525, 772, 352,
#         95, 380, 962, 526, 781, 360, 791,  96, 531, 782, 100, 161, 792,
#        981,  97, 532, 162, 533, 783, 963, 784, 163, 110, 534, 982, 550,
#        120, 785, 164, 540, 130, 560, 165, 983, 570, 140, 991, 992, 993,
#        994, 995, 984, 996, 150, 997, 985, 986, 998])
